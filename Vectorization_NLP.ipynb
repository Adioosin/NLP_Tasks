# %%
import nltk
import string

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.porter import PorterStemmer

# %%
text = "aditya is good at programming"
tokens = nltk.word_tokenize(text)
stems = []

for item in tokens:
    stems.append(PorterStemmer().stem(item))
    print(stems)
# Out:
# ['aditya']
# ['aditya', 'is']
# ['aditya', 'is', 'good']
# ['aditya', 'is', 'good', 'at']
# ['aditya', 'is', 'good', 'at', 'program']

# %%
def gender_feature(word):
    return{'last letter': word[-1]}

# %%
gender_feature('aditya')
# Out:
# {'last letter': 'a'}

# %%
from nltk.corpus import names

# %%
labelled_names = ([(name,'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])

# %%
labelled_names[5000:]
# Out:
# [('Gwen', 'female'),
#  ('Gwendolen', 'female'),
#  ('Gwendolin', 'female'),
#  ('Gwendolyn', 'female'),
#  ('Gweneth', 'female'),
#  ('Gwenette', 'female'),
#  ('Gwenn', 'female'),
#  ('Gwenneth', 'female'),
#  ('Gwenni', 'female'),
#  ('Gwennie', 'female'),
#  ('Gwenny', 'female'),
#  ('Gwenora', 'female'),
#  ('Gwenore', 'female'),
#  ('Gwyn', 'female'),
#  ('Gwyneth', 'female'),
#  ('Gwynne', 'female'),
#  ('Gypsy', 'female'),
#  ('Hadria', 'female'),
#  ('Hailee', 'female'),
#  ('Haily', 'female'),
#  ('Haleigh', 'female'),
#  ('Halette', 'female'),
#  ('Haley', 'female'),
#  ('Hali', 'female'),
#  ('Halie', 'female'),
#  ('Halimeda', 'female'),
#  ('Halley', 'female'),
#  ('Halli', 'female'),
#  ('Hallie', 'female'),
#  ('Hally', 'female'),
#  ('Hana', 'female'),
#  ('Hanna', 'female'),
#  ('Hannah', 'female'),
#  ('Hanni', 'female'),
#  ('Hannibal', 'female'),
#  ('Hannie', 'female'),
#  ('Hannis', 'female'),
#  ('Hanny', 'female'),
#  ('Happy', 'female'),
#  ('Harlene', 'female'),
#  ('Harley', 'female'),
#  ('Harli', 'female'),
#  ('Harlie', 'female'),
#  ('Harmonia', 'female'),
#  ('Harmonie', 'female'),
#  ('Harmony', 'female'),
#  ('Harri', 'female'),
#  ('Harrie', 'female'),
#  ('Harriet', 'female'),
#  ('Harriett', 'female'),
#  ('Harrietta', 'female'),
#  ('Harriette', 'female'),
#  ('Harriot', 'female'),
#  ('Harriott', 'female'),
#  ('Hatti', 'female'),
#  ('Hattie', 'female'),
#  ('Hatty', 'female'),
#  ('Havivah', 'female'),
#  ('Hayley', 'female'),
#  ('Hazel', 'female'),
#  ('Heath', 'female'),
#  ('Heather', 'female'),
#  ('Heda', 'female'),
#  ('Hedda', 'female'),
#  ('Heddi', 'female'),
#  ('Heddie', 'female'),
#  ('Hedi', 'female'),
#  ('Hedvig', 'female'),
#  ('Hedwig', 'female'),
#  ('Hedy', 'female'),
#  ('Heida', 'female'),
#  ('Heide', 'female'),
#  ('Heidi', 'female'),
#  ('Heidie', 'female'),
#  ('Helaina', 'female'),
#  ('Helaine', 'female'),
#  ('Helen', 'female'),
#  ('Helen-Elizabeth', 'female'),
#  ('Helena', 'female'),
#  ('Helene', 'female'),
#  ('Helga', 'female'),
#  ('Helge', 'female'),
#  ('Helise', 'female'),
#  ('Hellene', 'female'),
#  ('Helli', 'female'),
#  ('Heloise', 'female'),
#  ('Helsa', 'female'),
#  ('Helyn', 'female'),
#  ('Hendrika', 'female'),
#  ('Henka', 'female'),
#  ('Henrie', 'female'),
#  ('Henrieta', 'female'),
#  ('Henrietta', 'female'),
#  ('Henriette', 'female'),
#  ('Henryetta', 'female'),
#  ('Hephzibah', 'female'),
#  ('Hermia', 'female'),
#  ('Hermina', 'female'),
#  ('Hermine', 'female'),
#  ('Herminia', 'female'),
#  ('Hermione', 'female'),
#  ('Herta', 'female'),
#  ('Hertha', 'female'),
#  ('Hester', 'female'),
#  ('Hesther', 'female'),
#  ('Hestia', 'female'),
#  ('Hetti', 'female'),
#  ('Hettie', 'female'),
#  ('Hetty', 'female'),
#  ('Hilarie', 'female'),
#  ('Hilary', 'female'),
#  ('Hilda', 'female'),
#  ('Hildagard', 'female'),
#  ('Hildagarde', 'female'),
#  ('Hilde', 'female'),
#  ('Hildegaard', 'female'),
#  ('Hildegarde', 'female'),
#  ('Hildy', 'female'),
#  ('Hillary', 'female'),
#  ('Hilliary', 'female'),
#  ('Hinda', 'female'),
#  ('Holley', 'female'),
#  ('Holli', 'female'),
#  ('Hollie', 'female'),
#  ('Holly', 'female'),
#  ('Holly-Anne', 'female'),
#  ('Hollyanne', 'female'),
#  ('Honey', 'female'),
#  ('Honor', 'female'),
#  ('Honoria', 'female'),
#  ('Hope', 'female'),
#  ('Horatia', 'female'),
#  ('Hortense', 'female'),
#  ('Hortensia', 'female'),
#  ('Hulda', 'female'),
#  ('Hyacinth', 'female'),
#  ('Hyacintha', 'female'),
#  ('Hyacinthe', 'female'),
#  ('Hyacinthia', 'female'),
#  ('Hyacinthie', 'female'),
#  ('Hynda', 'female'),
#  ('Ianthe', 'female'),
#  ('Ibbie', 'female'),
#  ('Ibby', 'female'),
#  ('Ida', 'female'),
#  ('Idalia', 'female'),
#  ('Idalina', 'female'),
#  ('Idaline', 'female'),
#  ('Idell', 'female'),
#  ('Idelle', 'female'),
#  ('Idette', 'female'),
#  ('Ike', 'female'),
#  ('Ikey', 'female'),
#  ('Ilana', 'female'),
#  ('Ileana', 'female'),
#  ('Ileane', 'female'),
#  ('Ilene', 'female'),
#  ('Ilise', 'female'),
#  ('Ilka', 'female'),
#  ('Illa', 'female'),
#  ('Ilona', 'female'),
#  ('Ilsa', 'female'),
#  ('Ilse', 'female'),
#  ('Ilysa', 'female'),
#  ('Ilyse', 'female'),
#  ('Ilyssa', 'female'),
#  ('Imelda', 'female'),
#  ('Imogen', 'female'),
#  ('Imogene', 'female'),
#  ('Imojean', 'female'),
#  ('Ina', 'female'),
#  ('Inci', 'female'),
#  ('Indira', 'female'),
#  ('Ines', 'female'),
#  ('Inesita', 'female'),
#  ('Inessa', 'female'),
#  ('Inez', 'female'),
#  ('Inga', 'female'),
#  ('Ingaberg', 'female'),
#  ('Ingaborg', 'female'),
#  ('Inge', 'female'),
#  ('Ingeberg', 'female'),
#  ('Ingeborg', 'female'),
#  ('Inger', 'female'),
#  ('Ingrid', 'female'),
#  ('Ingunna', 'female'),
#  ('Inna', 'female'),
#  ('Ioana', 'female'),
#  ('Iolande', 'female'),
#  ('Iolanthe', 'female'),
#  ('Iona', 'female'),
#  ('Iormina', 'female'),
#  ('Ira', 'female'),
#  ('Irena', 'female'),
#  ('Irene', 'female'),
#  ('Irina', 'female'),
#  ('Iris', 'female'),
#  ('Irita', 'female'),
#  ('Irma', 'female'),
#  ('Isa', 'female'),
#  ('Isabeau', 'female'),
#  ('Isabel', 'female'),
#  ('Isabelita', 'female'),
#  ('Isabella', 'female'),
#  ('Isabelle', 'female'),
#  ('Isador', 'female'),
#  ('Isadora', 'female'),
#  ('Isadore', 'female'),
#  ('Isahella', 'female'),
#  ('Iseabal', 'female'),
#  ('Isidora', 'female'),
#  ('Isis', 'female'),
#  ('Isobel', 'female'),
#  ('Issi', 'female'),
#  ('Issie', 'female'),
#  ('Issy', 'female'),
#  ('Ivett', 'female'),
#  ('Ivette', 'female'),
#  ('Ivie', 'female'),
#  ('Ivonne', 'female'),
#  ('Ivory', 'female'),
#  ('Ivy', 'female'),
#  ('Izabel', 'female'),
#  ('Izzi', 'female'),
#  ('Jacenta', 'female'),
#  ('Jacinda', 'female'),
#  ('Jacinta', 'female'),
#  ('Jacintha', 'female'),
#  ('Jacinthe', 'female'),
#  ('Jackelyn', 'female'),
#  ('Jacki', 'female'),
#  ('Jackie', 'female'),
#  ('Jacklin', 'female'),
#  ('Jacklyn', 'female'),
#  ('Jackquelin', 'female'),
#  ('Jackqueline', 'female'),
#  ('Jacky', 'female'),
#  ('Jaclin', 'female'),
#  ('Jaclyn', 'female'),
#  ('Jacquelin', 'female'),
#  ('Jacqueline', 'female'),
#  ('Jacquelyn', 'female'),
#  ('Jacquelynn', 'female'),
#  ('Jacquenetta', 'female'),
#  ('Jacquenette', 'female'),
#  ('Jacquetta', 'female'),
#  ('Jacquette', 'female'),
#  ('Jacqui', 'female'),
#  ('Jacquie', 'female'),
#  ('Jacynth', 'female'),
#  ('Jada', 'female'),
#  ('Jade', 'female'),
#  ('Jaime', 'female'),
#  ('Jaimie', 'female'),
#  ('Jaine', 'female'),
#  ('Jaleh', 'female'),
#  ('Jami', 'female'),
#  ('Jamie', 'female'),
#  ('Jamima', 'female'),
#  ('Jammie', 'female'),
#  ('Jan', 'female'),
#  ('Jana', 'female'),
#  ('Janaya', 'female'),
#  ('Janaye', 'female'),
#  ('Jandy', 'female'),
#  ('Jane', 'female'),
#  ('Janean', 'female'),
#  ('Janeczka', 'female'),
#  ('Janeen', 'female'),
#  ('Janel', 'female'),
#  ('Janela', 'female'),
#  ('Janella', 'female'),
#  ('Janelle', 'female'),
#  ('Janene', 'female'),
#  ('Janenna', 'female'),
#  ('Janessa', 'female'),
#  ('Janet', 'female'),
#  ('Janeta', 'female'),
#  ('Janetta', 'female'),
#  ('Janette', 'female'),
#  ('Janeva', 'female'),
#  ('Janey', 'female'),
#  ('Jania', 'female'),
#  ('Janice', 'female'),
#  ('Janie', 'female'),
#  ('Janifer', 'female'),
#  ('Janina', 'female'),
#  ('Janine', 'female'),
#  ('Janis', 'female'),
#  ('Janith', 'female'),
#  ('Janka', 'female'),
#  ('Janna', 'female'),
#  ('Jannel', 'female'),
#  ('Jannelle', 'female'),
#  ('Janot', 'female'),
#  ('Jany', 'female'),
#  ('Jaquelin', 'female'),
#  ('Jaquelyn', 'female'),
#  ('Jaquenetta', 'female'),
#  ('Jaquenette', 'female'),
#  ('Jaquith', 'female'),
#  ('Jasmin', 'female'),
#  ('Jasmina', 'female'),
#  ('Jasmine', 'female'),
#  ('Jayme', 'female'),
#  ('Jaymee', 'female'),
#  ('Jayne', 'female'),
#  ('Jaynell', 'female'),
#  ('Jazmin', 'female'),
#  ('Jean', 'female'),
#  ('Jeana', 'female'),
#  ('Jeane', 'female'),
#  ('Jeanelle', 'female'),
#  ('Jeanette', 'female'),
#  ('Jeanie', 'female'),
#  ('Jeanine', 'female'),
#  ('Jeanna', 'female'),
#  ('Jeanne', 'female'),
#  ('Jeannette', 'female'),
#  ('Jeannie', 'female'),
#  ('Jeannine', 'female'),
#  ('Jehanna', 'female'),
#  ('Jelene', 'female'),
#  ('Jemie', 'female'),
#  ('Jemima', 'female'),
#  ('Jemimah', 'female'),
#  ('Jemmie', 'female'),
#  ('Jemmy', 'female'),
#  ('Jen', 'female'),
#  ('Jena', 'female'),
#  ('Jenda', 'female'),
#  ('Jenelle', 'female'),
#  ('Jenette', 'female'),
#  ('Jeni', 'female'),
#  ('Jenica', 'female'),
#  ('Jeniece', 'female'),
#  ('Jenifer', 'female'),
#  ('Jeniffer', 'female'),
#  ('Jenilee', 'female'),
#  ('Jenine', 'female'),
#  ('Jenn', 'female'),
#  ('Jenna', 'female'),
#  ('Jennee', 'female'),
#  ('Jennette', 'female'),
#  ('Jenni', 'female'),
#  ('Jennica', 'female'),
#  ('Jennie', 'female'),
#  ('Jennifer', 'female'),
#  ('Jennilee', 'female'),
#  ('Jennine', 'female'),
#  ('Jenny', 'female'),
#  ('Jeraldine', 'female'),
#  ('Jeralee', 'female'),
#  ('Jere', 'female'),
#  ('Jeri', 'female'),
#  ('Jermaine', 'female'),
#  ('Jerrie', 'female'),
#  ('Jerrilee', 'female'),
#  ('Jerrilyn', 'female'),
#  ('Jerrine', 'female'),
#  ('Jerry', 'female'),
#  ('Jerrylee', 'female'),
#  ('Jess', 'female'),
#  ('Jessa', 'female'),
#  ('Jessalin', 'female'),
#  ('Jessalyn', 'female'),
#  ('Jessamine', 'female'),
#  ('Jessamyn', 'female'),
#  ('Jesse', 'female'),
#  ('Jesselyn', 'female'),
#  ('Jessi', 'female'),
#  ('Jessica', 'female'),
#  ('Jessie', 'female'),
#  ('Jessika', 'female'),
#  ('Jessy', 'female'),
#  ('Jewel', 'female'),
#  ('Jewell', 'female'),
#  ('Jewelle', 'female'),
#  ('Jill', 'female'),
#  ('Jillana', 'female'),
#  ('Jillane', 'female'),
#  ('Jillayne', 'female'),
#  ('Jilleen', 'female'),
#  ('Jillene', 'female'),
#  ('Jilli', 'female'),
#  ('Jillian', 'female'),
#  ('Jillie', 'female'),
#  ('Jilly', 'female'),
#  ('Jinny', 'female'),
#  ('Jo', 'female'),
#  ('Jo Ann', 'female'),
#  ('Jo-Ann', 'female'),
#  ('JoAnn', 'female'),
#  ('Jo-Anne', 'female'),
#  ('JoAnne', 'female'),
#  ('Joan', 'female'),
#  ('Joana', 'female'),
#  ('Joane', 'female'),
#  ('Joanie', 'female'),
#  ('Joann', 'female'),
#  ('Joanna', 'female'),
#  ('Joanne', 'female'),
#  ('Joannes', 'female'),
#  ('Jobey', 'female'),
#  ('Jobi', 'female'),
#  ('Jobie', 'female'),
#  ('Jobina', 'female'),
#  ('Joby', 'female'),
#  ('Jobye', 'female'),
#  ('Jobyna', 'female'),
#  ('Jocelin', 'female'),
#  ('Joceline', 'female'),
#  ('Jocelyn', 'female'),
#  ('Jocelyne', 'female'),
#  ('Jodee', 'female'),
#  ('Jodi', 'female'),
#  ('Jodie', 'female'),
#  ('Jody', 'female'),
#  ('Joela', 'female'),
#  ('Joelie', 'female'),
#  ('Joell', 'female'),
#  ('Joella', 'female'),
#  ('Joelle', 'female'),
#  ('Joellen', 'female'),
#  ('Joelly', 'female'),
#  ('Joellyn', 'female'),
#  ('Joelynn', 'female'),
#  ('Joete', 'female'),
#  ('Joey', 'female'),
#  ('Johanna', 'female'),
#  ('Johannah', 'female'),
#  ('Johnette', 'female'),
#  ('Johnna', 'female'),
#  ('Joice', 'female'),
#  ('Jojo', 'female'),
#  ('Jolee', 'female'),
#  ('Joleen', 'female'),
#  ('Jolene', 'female'),
#  ('Joletta', 'female'),
#  ('Joli', 'female'),
#  ('Jolie', 'female'),
#  ('Joline', 'female'),
#  ('Joly', 'female'),
#  ('Jolyn', 'female'),
#  ('Jolynn', 'female'),
#  ('Jonell', 'female'),
#  ('Joni', 'female'),
#  ('Jonie', 'female'),
#  ('Jonis', 'female'),
#  ('Jordain', 'female'),
#  ('Jordan', 'female'),
#  ('Jordana', 'female'),
#  ('Jordanna', 'female'),
#  ('Jorey', 'female'),
#  ('Jori', 'female'),
#  ('Jorie', 'female'),
#  ('Jorrie', 'female'),
#  ('Jorry', 'female'),
#  ('Joscelin', 'female'),
#  ('Josee', 'female'),
#  ('Josefa', 'female'),
#  ('Josefina', 'female'),
#  ('Joselyn', 'female'),
#  ('Josepha', 'female'),
#  ('Josephina', 'female'),
#  ('Josephine', 'female'),
#  ('Josey', 'female'),
#  ('Josi', 'female'),
#  ('Josie', 'female'),
#  ('Joslyn', 'female'),
#  ('Josselyn', 'female'),
#  ('Josy', 'female'),
#  ('Jourdan', 'female'),
#  ('Joy', 'female'),
#  ('Joya', 'female'),
#  ('Joyan', 'female'),
#  ('Joyann', 'female'),
#  ('Joyce', 'female'),
#  ('Joycelin', 'female'),
#  ('Joye', 'female'),
#  ('Joyous', 'female'),
#  ('Juana', 'female'),
#  ('Juanita', 'female'),
#  ('Jude', 'female'),
#  ('Judi', 'female'),
#  ('Judie', 'female'),
#  ('Judith', 'female'),
#  ('Juditha', 'female'),
#  ('Judy', 'female'),
#  ('Judye', 'female'),
#  ('Julee', 'female'),
#  ('Juli', 'female'),
#  ('Julia', 'female'),
#  ('Juliana', 'female'),
#  ('Juliane', 'female'),
#  ('Juliann', 'female'),
#  ('Julianna', 'female'),
#  ('Julianne', 'female'),
#  ('Julie', 'female'),
#  ('Julienne', 'female'),
#  ('Juliet', 'female'),
#  ('Julieta', 'female'),
#  ('Julietta', 'female'),
#  ('Juliette', 'female'),
#  ('Julina', 'female'),
#  ('Juline', 'female'),
#  ('Julissa', 'female'),
#  ('Julita', 'female'),
#  ('June', 'female'),
#  ('Junette', 'female'),
#  ('Junia', 'female'),
#  ('Junie', 'female'),
#  ('Junina', 'female'),
#  ('Justin', 'female'),
#  ('Justina', 'female'),
#  ('Justine', 'female'),
#  ('Jyoti', 'female'),
#  ('Kaari', 'female'),
#  ('Kacey', 'female'),
#  ('Kacie', 'female'),
#  ('Kacy', 'female'),
#  ('Kai', 'female'),
#  ('Kaia', 'female'),
#  ('Kaila', 'female'),
#  ('Kaile', 'female'),
#  ('Kailey', 'female'),
#  ('Kaitlin', 'female'),
#  ('Kaitlyn', 'female'),
#  ('Kaitlynn', 'female'),
#  ('Kaja', 'female'),
#  ('Kakalina', 'female'),
#  ('Kala', 'female'),
#  ('Kaleena', 'female'),
#  ('Kali', 'female'),
#  ('Kalie', 'female'),
#  ('Kalila', 'female'),
#  ('Kalina', 'female'),
#  ('Kalinda', 'female'),
#  ('Kalindi', 'female'),
#  ('Kalli', 'female'),
#  ('Kally', 'female'),
#  ('Kameko', 'female'),
#  ('Kamila', 'female'),
#  ('Kamilah', 'female'),
#  ('Kamillah', 'female'),
#  ('Kandace', 'female'),
#  ('Kandy', 'female'),
#  ('Kania', 'female'),
#  ('Kanya', 'female'),
#  ('Kara', 'female'),
#  ('Kara-Lynn', 'female'),
#  ('Karalee', 'female'),
#  ('Karalynn', 'female'),
#  ('Kare', 'female'),
#  ('Karee', 'female'),
#  ('Karel', 'female'),
#  ('Karen', 'female'),
#  ('Karena', 'female'),
#  ('Kari', 'female'),
#  ('Karia', 'female'),
#  ('Karie', 'female'),
#  ('Karil', 'female'),
#  ('Karilynn', 'female'),
#  ('Karin', 'female'),
#  ('Karina', 'female'),
#  ('Karine', 'female'),
#  ('Kariotta', 'female'),
#  ('Karisa', 'female'),
#  ('Karissa', 'female'),
#  ('Karita', 'female'),
#  ('Karla', 'female'),
#  ('Karlee', 'female'),
#  ('Karleen', 'female'),
#  ('Karlen', 'female'),
#  ('Karlene', 'female'),
#  ('Karlie', 'female'),
#  ('Karlotta', 'female'),
#  ('Karlotte', 'female'),
#  ('Karly', 'female'),
#  ('Karlyn', 'female'),
#  ('Karmen', 'female'),
#  ('Karna', 'female'),
#  ('Karol', 'female'),
#  ('Karola', 'female'),
#  ('Karole', 'female'),
#  ('Karolina', 'female'),
#  ('Karoline', 'female'),
#  ('Karoly', 'female'),
#  ('Karon', 'female'),
#  ('Karrah', 'female'),
#  ('Karrie', 'female'),
#  ('Karry', 'female'),
#  ('Kary', 'female'),
#  ('Karyl', 'female'),
#  ('Karylin', 'female'),
#  ('Karyn', 'female'),
#  ('Kasey', 'female'),
#  ('Kass', 'female'),
#  ('Kassandra', 'female'),
#  ('Kassey', 'female'),
#  ('Kassi', 'female'),
#  ('Kassia', 'female'),
#  ('Kassie', 'female'),
#  ('Kaster', 'female'),
#  ('Kat', 'female'),
#  ('Kata', 'female'),
#  ('Katalin', 'female'),
#  ('Kate', 'female'),
#  ('Katee', 'female'),
#  ('Katerina', 'female'),
#  ('Katerine', 'female'),
#  ('Katey', 'female'),
#  ('Kath', 'female'),
#  ('Katha', 'female'),
#  ('Katharina', 'female'),
#  ('Katharine', 'female'),
#  ('Katharyn', 'female'),
#  ('Kathe', 'female'),
#  ('Katheleen', 'female'),
#  ('Katherina', 'female'),
#  ('Katherine', 'female'),
#  ('Katheryn', 'female'),
#  ('Kathi', 'female'),
#  ('Kathie', 'female'),
#  ('Kathleen', 'female'),
#  ('Kathlene', 'female'),
#  ('Kathlin', 'female'),
#  ('Kathrine', 'female'),
#  ('Kathryn', 'female'),
#  ('Kathryne', 'female'),
#  ('Kathy', 'female'),
#  ('Kathye', 'female'),
#  ('Kati', 'female'),
#  ('Katie', 'female'),
#  ('Katina', 'female'),
#  ('Katine', 'female'),
#  ('Katinka', 'female'),
#  ('Katleen', 'female'),
#  ('Katlin', 'female'),
#  ('Katrina', 'female'),
#  ('Katrine', 'female'),
#  ('Katrinka', 'female'),
#  ('Katti', 'female'),
#  ('Kattie', 'female'),
#  ('Katuscha', 'female'),
#  ('Katusha', 'female'),
#  ('Katy', 'female'),
#  ('Katya', 'female'),
#  ('Kay', 'female'),
#  ('Kaycee', 'female'),
#  ('Kaye', 'female'),
#  ('Kayla', 'female'),
#  ('Kayle', 'female'),
#  ('Kaylee', 'female'),
#  ('Kayley', 'female'),
#  ('Kaylil', 'female'),
#  ('Kaylyn', 'female'),
#  ('Kee', 'female'),
#  ('Keeley', 'female'),
#  ('Keelia', 'female'),
#  ('Keely', 'female'),
#  ('Kelcey', 'female'),
#  ('Kelci', 'female'),
#  ('Kelcie', 'female'),
#  ('Kelcy', 'female'),
#  ('Kelila', 'female'),
#  ('Kellen', 'female'),
#  ('Kelley', 'female'),
#  ('Kelli', 'female'),
#  ('Kellia', 'female'),
#  ('Kellie', 'female'),
#  ('Kellina', 'female'),
#  ('Kellsie', 'female'),
#  ('Kelly', 'female'),
#  ('Kellyann', 'female'),
#  ('Kelsey', 'female'),
#  ('Kelsi', 'female'),
#  ('Kelsy', 'female'),
#  ('Kendra', 'female'),
#  ('Kendre', 'female'),
#  ('Kenna', 'female'),
#  ('Keren', 'female'),
#  ('Keri', 'female'),
#  ('Keriann', 'female'),
#  ('Kerianne', 'female'),
#  ('Kerri', 'female'),
#  ('Kerrie', 'female'),
#  ('Kerrill', 'female'),
#  ('Kerrin', 'female'),
#  ('Kerry', 'female'),
#  ('Kerstin', 'female'),
#  ('Kesley', 'female'),
#  ('Keslie', 'female'),
#  ('Kessia', 'female'),
#  ('Kessiah', 'female'),
#  ('Ketti', 'female'),
#  ('Kettie', 'female'),
#  ('Ketty', 'female'),
#  ('Kevina', 'female'),
#  ('Kevyn', 'female'),
#  ('Ki', 'female'),
#  ('Kia', 'female'),
#  ('Kiah', 'female'),
#  ('Kial', 'female'),
#  ('Kiele', 'female'),
#  ('Kiersten', 'female'),
#  ('Kikelia', 'female'),
#  ('Kiley', 'female'),
#  ('Kim', 'female'),
#  ('Kimberlee', 'female'),
#  ('Kimberley', 'female'),
#  ('Kimberli', 'female'),
#  ('Kimberly', 'female'),
#  ('Kimberlyn', 'female'),
#  ('Kimbra', 'female'),
#  ('Kimmi', 'female'),
#  ('Kimmie', 'female'),
#  ('Kimmy', 'female'),
#  ('Kinna', 'female'),
#  ('Kip', 'female'),
#  ('Kipp', 'female'),
#  ('Kippie', 'female'),
#  ('Kippy', 'female'),
#  ('Kira', 'female'),
#  ('Kirbee', 'female'),
#  ('Kirbie', 'female'),
#  ('Kirby', 'female'),
#  ('Kiri', 'female'),
#  ('Kirsten', 'female'),
#  ('Kirsteni', 'female'),
#  ('Kirsti', 'female'),
#  ('Kirstie', 'female'),
#  ('Kirstin', 'female'),
#  ('Kirstyn', 'female'),
#  ('Kissee', 'female'),
#  ('Kissiah', 'female'),
#  ('Kissie', 'female'),
#  ('Kit', 'female'),
#  ('Kitti', 'female'),
#  ('Kittie', 'female'),
#  ('Kitty', 'female'),
#  ('Kizzee', 'female'),
#  ('Kizzie', 'female'),
#  ('Klara', 'female'),
#  ('Klarika', 'female'),
#  ('Klarrisa', 'female'),
#  ('Konstance', 'female'),
#  ('Konstanze', 'female'),
#  ('Koo', 'female'),
#  ('Kora', 'female'),
#  ('Koral', 'female'),
#  ('Koralle', 'female'),
#  ('Kordula', 'female'),
#  ('Kore', 'female'),
#  ('Korella', 'female'),
#  ('Koren', 'female'),
#  ('Koressa', 'female'),
#  ('Kori', 'female'),
#  ('Korie', 'female'),
#  ('Korney', 'female'),
#  ('Korrie', 'female'),
#  ('Korry', 'female'),
#  ('Kourtney', 'female'),
#  ('Kris', 'female'),
#  ('Krissie', 'female'),
#  ('Krissy', 'female'),
#  ('Krista', 'female'),
#  ('Kristal', 'female'),
#  ('Kristan', 'female'),
#  ('Kriste', 'female'),
#  ('Kristel', 'female'),
#  ('Kristen', 'female'),
#  ('Kristi', 'female'),
#  ('Kristien', 'female'),
#  ('Kristin', 'female'),
#  ('Kristina', 'female'),
#  ('Kristine', 'female'),
#  ('Kristy', 'female'),
#  ('Kristyn', 'female'),
#  ('Krysta', 'female'),
#  ('Krystal', 'female'),
#  ('Krystalle', 'female'),
#  ('Krystle', 'female'),
#  ('Krystyna', 'female'),
#  ('Kyla', 'female'),
#  ('Kyle', 'female'),
#  ('Kylen', 'female'),
#  ('Kylie', 'female'),
#  ('Kylila', 'female'),
#  ('Kylynn', 'female'),
#  ('Kym', 'female'),
#  ('Kynthia', 'female'),
#  ('Kyrstin', 'female'),
#  ('La', 'female'),
#  ('Lacee', 'female'),
#  ('Lacey', 'female'),
#  ('Lacie', 'female'),
#  ('Lacy', 'female'),
#  ('Ladonna', 'female'),
#  ('Laetitia', 'female'),
#  ('Laila', 'female'),
#  ('Laina', 'female'),
#  ('Lainey', 'female'),
#  ('Lamb', 'female'),
#  ('Lana', 'female'),
#  ('Lane', 'female'),
#  ('Lanette', 'female'),
#  ('Laney', 'female'),
#  ('Lani', 'female'),
#  ('Lanie', 'female'),
#  ('Lanita', 'female'),
#  ('Lanna', 'female'),
#  ('Lanni', 'female'),
#  ('Lanny', 'female'),
#  ('Lara', 'female'),
#  ('Laraine', 'female'),
#  ('Lari', 'female'),
#  ('Larina', 'female'),
#  ('Larine', 'female'),
#  ('Larisa', 'female'),
#  ('Larissa', 'female'),
#  ('Lark', 'female'),
#  ('Laryssa', 'female'),
#  ('Latashia', 'female'),
#  ('Latia', 'female'),
#  ('Latisha', 'female'),
#  ('Latrena', 'female'),
#  ('Latrina', 'female'),
#  ('Laura', 'female'),
#  ('Lauraine', 'female'),
#  ('Laural', 'female'),
#  ('Lauralee', 'female'),
#  ('Laure', 'female'),
#  ('Lauree', 'female'),
#  ('Laureen', 'female'),
#  ('Laurel', 'female'),
#  ('Laurella', 'female'),
#  ('Lauren', 'female'),
#  ('Laurena', 'female'),
#  ('Laurene', 'female'),
#  ('Lauretta', 'female'),
#  ('Laurette', 'female'),
#  ('Lauri', 'female'),
#  ('Laurianne', 'female'),
#  ('Laurice', 'female'),
#  ('Laurie', 'female'),
#  ('Lauryn', 'female'),
#  ('Lavena', 'female'),
#  ('Laverna', 'female'),
#  ('Laverne', 'female'),
#  ('Lavina', 'female'),
#  ('Lavinia', 'female'),
#  ('Lavinie', 'female'),
#  ('Layla', 'female'),
#  ('Layne', 'female'),
#  ('Layney', 'female'),
#  ('Lea', 'female'),
#  ('Leah', 'female'),
#  ('Leandra', 'female'),
#  ('Leann', 'female'),
#  ('Leanna', 'female'),
#  ('Leanne', 'female'),
#  ('Leanor', 'female'),
#  ('Leanora', 'female'),
#  ('Lebbie', 'female'),
#  ('Leda', 'female'),
#  ('Lee', 'female'),
#  ('LeeAnn', 'female'),
#  ('Leeann', 'female'),
#  ('Leeanne', 'female'),
#  ('Leela', 'female'),
#  ('Leelah', 'female'),
#  ('Leena', 'female'),
#  ('Leesa', 'female'),
#  ('Leese', 'female'),
#  ('Legra', 'female'),
#  ('Leia', 'female'),
#  ('Leiah', 'female'),
#  ('Leigh', 'female'),
#  ('Leigha', 'female'),
#  ('Leila', 'female'),
#  ('Leilah', 'female'),
#  ('Leisha', 'female'),
#  ('Lela', 'female'),
#  ('Lelah', 'female'),
#  ('Leland', 'female'),
#  ('Lelia', 'female'),
#  ('Lena', 'female'),
#  ('Lenee', 'female'),
#  ('Lenette', 'female'),
#  ('Lenka', 'female'),
#  ('Lenna', 'female'),
#  ('Lenora', 'female'),
#  ('Lenore', 'female'),
#  ('Leodora', 'female'),
#  ('Leoine', 'female'),
#  ('Leola', 'female'),
#  ('Leoline', 'female'),
#  ('Leona', 'female'),
#  ('Leonanie', 'female'),
#  ('Leone', 'female'),
#  ('Leonelle', 'female'),
#  ('Leonie', 'female'),
#  ('Leonora', 'female'),
#  ('Leonore', 'female'),
#  ('Leontine', 'female'),
#  ('Leontyne', 'female'),
#  ('Leora', 'female'),
#  ('Leorah', 'female'),
#  ('Leshia', 'female'),
#  ('Lesley', 'female'),
#  ('Lesli', 'female'),
#  ('Leslie', 'female'),
#  ('Lesly', 'female'),
#  ('Lesya', 'female'),
#  ('Leta', 'female'),
#  ('Lethia', 'female'),
#  ('Leticia', 'female'),
#  ('Letisha', 'female'),
#  ('Letitia', 'female'),
#  ('Letta', 'female'),
#  ('Letti', 'female'),
#  ('Lettie', 'female'),
#  ('Letty', 'female'),
#  ('Leyla', 'female'),
#  ('Lezlie', 'female'),
#  ('Lia', 'female'),
#  ('Lian', 'female'),
#  ('Liana', 'female'),
#  ('Liane', 'female'),
#  ('Lianna', 'female'),
#  ('Lianne', 'female'),
#  ('Lib', 'female'),
#  ('Libbey', 'female'),
#  ('Libbi', 'female'),
#  ('Libbie', 'female'),
#  ('Libby', 'female'),
#  ('Licha', 'female'),
#  ('Lida', 'female'),
#  ('Lidia', 'female'),
#  ('Lil', 'female'),
#  ('Lila', 'female'),
#  ('Lilah', 'female'),
#  ('Lilas', 'female'),
#  ('Lilia', 'female'),
#  ('Lilian', 'female'),
#  ('Liliane', 'female'),
#  ('Lilias', 'female'),
#  ('Lilith', 'female'),
#  ('Lilla', 'female'),
#  ('Lilli', 'female'),
#  ('Lillian', 'female'),
#  ('Lillis', 'female'),
#  ('Lilllie', 'female'),
#  ('Lilly', 'female'),
#  ('Lily', 'female'),
#  ('Lilyan', 'female'),
#  ('Lin', 'female'),
#  ('Lina', 'female'),
#  ('Lind', 'female'),
#  ('Linda', 'female'),
#  ('Lindi', 'female'),
#  ('Lindie', 'female'),
#  ('Lindsay', 'female'),
#  ('Lindsey', 'female'),
#  ('Lindsy', 'female'),
#  ('Lindy', 'female'),
#  ('Linea', 'female'),
#  ('Linell', 'female'),
#  ('Linet', 'female'),
#  ('Linette', 'female'),
#  ('Linn', 'female'),
#  ('Linnea', 'female'),
#  ('Linnell', 'female'),
#  ('Linnet', 'female'),
#  ('Linnie', 'female'),
#  ('Linzy', 'female'),
#  ('Liora', 'female'),
#  ('Liorah', 'female'),
#  ('Lira', 'female'),
#  ('Lisa', 'female'),
#  ('Lisabeth', 'female'),
#  ('Lisandra', 'female'),
#  ('Lisbeth', 'female'),
#  ('Lise', 'female'),
#  ('Lisetta', 'female'),
#  ('Lisette', 'female'),
#  ('Lisha', 'female'),
#  ('Lishe', 'female'),
#  ('Lissa', 'female'),
#  ('Lissi', 'female'),
#  ('Lissie', 'female'),
#  ('Lissy', 'female'),
#  ('Lita', 'female'),
#  ('Liuka', 'female'),
#  ('Livia', 'female'),
#  ('Liz', 'female'),
#  ('Liza', 'female'),
#  ('Lizabeth', 'female'),
#  ('Lizbeth', 'female'),
#  ...]

# %%
import random

random.shuffle(labelled_names)


featuresets = [(gender_feature(n), gender) for (n,gender) in labelled_names]

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)
classifier.classify(gender_feature('vishisht'))
# Out:
# 'male'

# %%
classifier.classify(gender_feature('aditi'))
# Out:
# 'female'

# %%
classifier.classify(gender_feature('aarushi'))
# Out:
# 'female'

# %%
classifier.classify(gender_feature('tejas'))
# Out:
# 'male'

# %%
classifier.classify(gender_feature('sandesh'))
# Out:
# 'female'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.784
